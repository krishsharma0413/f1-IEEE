# %%
import lightgbm as lgb
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd
from sklearn.preprocessing import LabelEncoder
# from sklearn.model_selection import train_test_split

# %%
train_df = pd.read_csv("./data/train.csv")
train_df.head()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_4316\3030752658.py:1: DtypeWarning: Columns (4,13,14,16,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = pd.read_csv("./data/train.csv")
#    resultId  racerId  driverId  constructorId number  grid position_x  \
# 0     20025      833       642             51      2     1          1
# 1     20025      833       642             51      2     1          1
# 2     20025      833       642             51      2     1          1
# 3     20025      833       642             51      2     1          1
# 4     20025      833       642             51      2     1          1
#
#   positionText_x  positionOrder  points  ...  points_y position  \
# 0              1              1     9.0  ...      3.33        3
# 1              1              1     9.0  ...      6.33        3
# 2              1              1     9.0  ...      6.33        4
# 3              1              1     9.0  ...     10.33        3
# 4              1              1     9.0  ...     10.33        4
#
#   positionText_y wins constructorRef     company nationality_y  \
# 0              3    0           alfa  Alfa Romeo         Swiss
# 1              3    0           alfa  Alfa Romeo         Swiss
# 2              4    0           alfa  Alfa Romeo         Swiss
# 3              3    0           alfa  Alfa Romeo         Swiss
# 4              4    0           alfa  Alfa Romeo         Swiss
#
#                                                  url    status  \
# 0  http://en.wikipedia.org/wiki/Alfa_Romeo_in_For...  Finished
# 1  http://en.wikipedia.org/wiki/Alfa_Romeo_in_For...  Finished
# 2  http://en.wikipedia.org/wiki/Alfa_Romeo_in_For...  Finished
# 3  http://en.wikipedia.org/wiki/Alfa_Romeo_in_For...  Finished
# 4  http://en.wikipedia.org/wiki/Alfa_Romeo_in_For...  Finished
#
#    result_driver_standing
# 0               922731975
# 1               923172525
# 2               923833350
# 3               925195050
# 4               926576775
#
# [5 rows x 55 columns]

# %%
test_df = pd.read_csv("./data/test.csv")
test_df.head()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_4316\2707460454.py:1: DtypeWarning: Columns (13,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   test_df = pd.read_csv("./data/test.csv")
#    resultId  racerId  driverId  constructorId  number  grid position_x  \
# 0     23949      997         4              1      14    13          8
# 1     23949      997         4              1      14    13          8
# 2     23949      997         4              1      14    13          8
# 3     23949      997         4              1      14    13          8
# 4     23949      997         4              1      14    13          8
#
#   positionText_x  positionOrder  points  ...  driverStandingsId raceId_y  \
# 0              8              8     4.0  ...              12474       93
# 1              8              8     4.0  ...              12494       94
# 2              8              8     4.0  ...              12514       95
# 3              8              8     4.0  ...              12534       96
# 4              8              8     4.0  ...              12554       97
#
#   points_y wins  constructorRef  company nationality_y  \
# 0     16.0    0         mclaren  McLaren       British
# 1     21.0    0         mclaren  McLaren       British
# 2     21.0    0         mclaren  McLaren       British
# 3     25.0    0         mclaren  McLaren       British
# 4     25.0    0         mclaren  McLaren       British
#
#                                     url  status  result_driver_standing
# 0  http://en.wikipedia.org/wiki/McLaren  +1 Lap               298739826
# 1  http://en.wikipedia.org/wiki/McLaren  +1 Lap               299218806
# 2  http://en.wikipedia.org/wiki/McLaren  +1 Lap               299697786
# 3  http://en.wikipedia.org/wiki/McLaren  +1 Lap               300176766
# 4  http://en.wikipedia.org/wiki/McLaren  +1 Lap               300655746
#
# [5 rows x 53 columns]

# %%
validation_df = pd.read_csv("./data/validation.csv")
validation_df.head()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_4316\3375616066.py:1: DtypeWarning: Columns (13,16,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   validation_df = pd.read_csv("./data/validation.csv")
#    resultId  racerId  driverId  constructorId  number  grid position_x  \
# 0     22109      899        17              9       2     4          2
# 1     22109      899        17              9       2     4          2
# 2     22109      899        17              9       2     4          2
# 3     22109      899        17              9       2     4          2
# 4     22109      899        17              9       2     4          2
#
#   positionText_x  positionOrder  points  ...  points_y position  \
# 0              2              2    18.0  ...      28.0        8
# 1              2              2    18.0  ...      53.0        4
# 2              2              2    18.0  ...      78.0        1
# 3              2              2    18.0  ...      93.0        1
# 4              2              2    18.0  ...     103.0        3
#
#   positionText_y wins  constructorRef   company nationality_y  \
# 0              8    0        red_bull  Red Bull      Austrian
# 1              4    1        red_bull  Red Bull      Austrian
# 2              1    2        red_bull  Red Bull      Austrian
# 3              1    2        red_bull  Red Bull      Austrian
# 4              3    2        red_bull  Red Bull      Austrian
#
#                                             url    status  \
# 0  http://en.wikipedia.org/wiki/Red_Bull_Racing  Finished
# 1  http://en.wikipedia.org/wiki/Red_Bull_Racing  Finished
# 2  http://en.wikipedia.org/wiki/Red_Bull_Racing  Finished
# 3  http://en.wikipedia.org/wiki/Red_Bull_Racing  Finished
# 4  http://en.wikipedia.org/wiki/Red_Bull_Racing  Finished
#
#    result_driver_standing
# 0              1410907944
# 1              1411438560
# 2              1412499792
# 3              1413030408
# 4              1413561024
#
# [5 rows x 55 columns]

# %%
new_train_df = train_df[
    ["result_driver_standing", "points_y", "company", "round",
     "wins", "grand_prix", "year", "points", "positionOrder",
     "resultId", "racerId", "position"]]
new_train_df.head()
# Out:
#    result_driver_standing  points_y     company  round  wins  \
# 0               922731975      3.33  Alfa Romeo      1     0
# 1               923172525      6.33  Alfa Romeo      1     0
# 2               923833350      6.33  Alfa Romeo      1     0
# 3               925195050     10.33  Alfa Romeo      1     0
# 4               926576775     10.33  Alfa Romeo      1     0
#
#            grand_prix  year  points  positionOrder  resultId  racerId  \
# 0  British Grand Prix  1950     9.0              1     20025      833
# 1  British Grand Prix  1950     9.0              1     20025      833
# 2  British Grand Prix  1950     9.0              1     20025      833
# 3  British Grand Prix  1950     9.0              1     20025      833
# 4  British Grand Prix  1950     9.0              1     20025      833
#
#    position
# 0         3
# 1         3
# 2         4
# 3         3
# 4         4

# %%
new_validation_df = validation_df[
    ["result_driver_standing", "points_y", "company", "round",
     "wins", "grand_prix", "year", "points", "positionOrder",
     "resultId", "racerId", "position"]]
new_validation_df.head()
# Out:
#    result_driver_standing  points_y   company  round  wins  \
# 0              1410907944      28.0  Red Bull     19     0
# 1              1411438560      53.0  Red Bull     19     1
# 2              1412499792      78.0  Red Bull     19     2
# 3              1413030408      93.0  Red Bull     19     2
# 4              1413561024     103.0  Red Bull     19     2
#
#              grand_prix  year  points  positionOrder  resultId  racerId  \
# 0  Brazilian Grand Prix  2013    18.0              2     22109      899
# 1  Brazilian Grand Prix  2013    18.0              2     22109      899
# 2  Brazilian Grand Prix  2013    18.0              2     22109      899
# 3  Brazilian Grand Prix  2013    18.0              2     22109      899
# 4  Brazilian Grand Prix  2013    18.0              2     22109      899
#
#    position
# 0         8
# 1         4
# 2         1
# 3         1
# 4         3

# %%
new_test_df = test_df[
    ["result_driver_standing", "points_y", "company", "round",
    "wins", "grand_prix", "year", "points", "positionOrder",
     "resultId", "racerId"]]
new_test_df
# Out:
#         result_driver_standing  points_y  company  round  wins  \
# 0                    298739826      16.0  McLaren      9     0
# 1                    299218806      21.0  McLaren      9     0
# 2                    299697786      21.0  McLaren      9     0
# 3                    300176766      25.0  McLaren      9     0
# 4                    300655746      25.0  McLaren      9     0
# ...                        ...       ...      ...    ...   ...
# 352923              1880337225       5.0  McLaren     12     0
# 352924              1881380625       5.0  McLaren     12     0
# 352925              1881902325      17.0  McLaren     12     0
# 352926              1882424025      27.0  McLaren     12     0
# 352927              1882971810      34.0  McLaren     12     0
#
#                  grand_prix  year  points  positionOrder  resultId  racerId
# 0       Austrian Grand Prix  2018     4.0              8     23949      997
# 1       Austrian Grand Prix  2018     4.0              8     23949      997
# 2       Austrian Grand Prix  2018     4.0              8     23949      997
# 3       Austrian Grand Prix  2018     4.0              8     23949      997
# 4       Austrian Grand Prix  2018     4.0              8     23949      997
# ...                     ...   ...     ...            ...       ...      ...
# 352923   Belgian Grand Prix  2023     0.0             20     26085     1110
# 352924   Belgian Grand Prix  2023     0.0             20     26085     1110
# 352925   Belgian Grand Prix  2023     0.0             20     26085     1110
# 352926   Belgian Grand Prix  2023     0.0             20     26085     1110
# 352927   Belgian Grand Prix  2023     0.0             20     26085     1110
#
# [352928 rows x 11 columns]

# %%
# finished_train = new_train_df[new_train_df["status"] == "Finished"]

finished_train = new_train_df
# finished_train.loc[finished_train['status'] != 'Finished', 'status'] = 'Unfinished'

# %%
# finished_test = new_test_df[new_test_df["status"] == "Finished"]
finished_test = new_test_df
# finished_test.loc[finished_test['status'] != 'Finished', 'status'] = 'Unfinished'

# %%
# finished_validation = new_validation_df[new_validation_df["status"] == "Finished"]
finished_validation = new_validation_df
# finished_validation.loc[finished_validation['status'] != 'Finished', 'status'] = 'Unfinished'

# %%
finished_train = finished_train.fillna(0)
finished_test = finished_test.fillna(0)
finished_validation = finished_validation.fillna(0)

# %%
# encoding all columns
label_encoders = {}
for column in ['company', 'grand_prix']:
    le = LabelEncoder()
    finished_train[column] = le.fit_transform(finished_train[column])
    label_encoders[column] = le
    
label_encoders = {}
for column in ['company', 'grand_prix']:
    le = LabelEncoder()
    finished_test[column] = le.fit_transform(finished_test[column])
    label_encoders[column] = le

label_encoders = {}
for column in ['company', 'grand_prix']:
    le = LabelEncoder()
    finished_validation[column] = le.fit_transform(finished_validation[column])
    label_encoders[column] = le

# %%
params = {
    'objective': 'regression',
    'metric': 'rmse',  # RMSE for regression
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'device': 'gpu',  # Use GPU for training
    'gpu_platform_id': 0,  # Specify GPU platform ID (0 by default)
    'gpu_device_id': 0  # Specify GPU device ID (0 by default)
}

# %%
X_train = finished_train.drop(columns=['position'])
y_train = finished_train['position']

X_test = finished_validation.drop(columns=['position'])
y_test = finished_validation['position']

predictkardo = finished_test
predictkardo
# y_test = finished_test['position']
# Out:
#         result_driver_standing  points_y  company  round  wins  grand_prix  \
# 0                    298739826      16.0        7      9     0           3
# 1                    299218806      21.0        7      9     0           3
# 2                    299697786      21.0        7      9     0           3
# 3                    300176766      25.0        7      9     0           3
# 4                    300655746      25.0        7      9     0           3
# ...                        ...       ...      ...    ...   ...         ...
# 352923              1880337225       5.0        7     12     0           6
# 352924              1881380625       5.0        7     12     0           6
# 352925              1881902325      17.0        7     12     0           6
# 352926              1882424025      27.0        7     12     0           6
# 352927              1882971810      34.0        7     12     0           6
#
#         year  points  positionOrder  resultId  racerId
# 0          0     4.0              8     23949      997
# 1          0     4.0              8     23949      997
# 2          0     4.0              8     23949      997
# 3          0     4.0              8     23949      997
# 4          0     4.0              8     23949      997
# ...      ...     ...            ...       ...      ...
# 352923     5     0.0             20     26085     1110
# 352924     5     0.0             20     26085     1110
# 352925     5     0.0             20     26085     1110
# 352926     5     0.0             20     26085     1110
# 352927     5     0.0             20     26085     1110
#
# [352928 rows x 11 columns]

# %%
train_data = lgb.Dataset(X_train, label=y_train)
test_data = lgb.Dataset(X_test, label=y_test, reference=train_data)

# Train the model
num_round = 5000
bst = lgb.train(params, train_data, num_round, valid_sets=[test_data])
# Out:
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 2830101, number of used features: 11
# [LightGBM] [Info] Using requested OpenCL platform 0 device 0
# [LightGBM] [Info] Using GPU Device: gfx1035, Vendor: Advanced Micro Devices, Inc.
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (32.39 MB) transferred to GPU in 0.040663 secs. 1 sparse feature groups
# [LightGBM] [Info] Start training from score 12.332001
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.022561 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.021202 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.023695 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.021317 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.021923 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.022325 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026358 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.020980 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.021448 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.021121 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.022001 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.022494 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.020952 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.019704 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.020837 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.020586 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.020430 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.021332 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.021950 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.031389 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.021419 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.021043 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.021937 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.021233 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.021293 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.020612 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.019867 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.93 MB) transferred to GPU in 0.028681 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.027846 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.024870 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027730 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026153 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.032736 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026450 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.028387 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.026071 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.027255 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.027084 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.031254 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.028478 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.025233 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026418 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027239 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.022680 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.020865 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.020263 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.019943 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.020500 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.020674 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.020717 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.022716 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.020341 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.020692 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.021007 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.019701 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.019727 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.023004 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.020328 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.022363 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.024462 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.022140 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.021092 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.021284 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.022167 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.021280 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.021934 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.021024 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.022276 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.021507 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.024317 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.022063 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.021132 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.021674 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.022275 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.022422 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.021887 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.022783 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.022093 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.022428 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.021174 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025975 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.021269 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.020889 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.019847 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.021666 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.020314 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.021784 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.019547 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.020856 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.019738 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.020557 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.020911 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.020378 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.020840 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.019679 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.020812 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.021256 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.021704 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.020463 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.020520 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.021838 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.020918 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.023925 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.023767 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025879 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.023751 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025324 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025369 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025743 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027026 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.025286 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.025918 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.028037 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.025512 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025043 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.025562 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.024965 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.025024 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.025302 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026074 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026214 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.028943 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.027677 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.026961 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.025250 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026723 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.024954 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025485 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027393 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.024998 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.023602 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027092 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.026347 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.89 MB) transferred to GPU in 0.026166 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.027481 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.026433 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.024311 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025405 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.031715 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025504 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025231 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025935 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.021829 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026607 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.024528 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.024677 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025136 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025552 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026267 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.025731 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.024998 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.022584 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.022121 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.027808 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.026948 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.024962 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026971 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025129 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.023346 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.025421 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.93 MB) transferred to GPU in 0.026218 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025474 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.037817 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026822 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025020 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.025721 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026302 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.025968 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025171 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025947 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.037428 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.027056 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.027651 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.026558 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.025427 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.025435 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025310 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025716 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025340 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.024694 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026190 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.024724 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026710 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026176 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.025505 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025176 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025413 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025152 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026420 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.026317 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.89 MB) transferred to GPU in 0.025390 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.93 MB) transferred to GPU in 0.024417 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026285 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.024291 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025042 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026639 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.026221 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.026176 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.024422 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.029756 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.028057 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.93 MB) transferred to GPU in 0.025670 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.025459 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.024853 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.024788 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.023925 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.024606 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.026428 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025849 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.025314 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025259 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025589 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.024206 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025597 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.023809 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.024753 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.89 MB) transferred to GPU in 0.026044 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.93 MB) transferred to GPU in 0.024805 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025009 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.024678 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.026523 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.023941 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.025837 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026166 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.023894 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025694 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.024139 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.026317 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.023510 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.026251 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025987 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027484 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025388 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025227 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.025997 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025602 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026104 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026587 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.025789 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.026619 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027097 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027154 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025987 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.025416 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026864 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.024404 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027686 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025256 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027184 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.027915 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.024546 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025884 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026231 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027377 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.025832 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025374 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.89 MB) transferred to GPU in 0.025245 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.023023 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026145 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026869 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.93 MB) transferred to GPU in 0.025185 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026675 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.027082 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.025830 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.027186 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026229 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.023892 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.026102 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.024365 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026243 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027739 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.024173 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.024959 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.024890 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025548 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.025696 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.024883 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.026496 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.93 MB) transferred to GPU in 0.026232 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.025896 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.024403 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.025188 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.025869 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027891 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027284 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.027607 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.028216 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027085 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.025233 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026107 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026490 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.93 MB) transferred to GPU in 0.024553 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# ...
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.032405 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.028409 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.028546 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.028896 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.88 MB) transferred to GPU in 0.029094 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.028455 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027003 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.88 MB) transferred to GPU in 0.028526 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.030005 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.027427 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.028751 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.032049 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.031349 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.029150 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.028262 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.028397 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.029413 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.029595 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.029146 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.028872 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027529 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.029142 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027567 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026602 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.028612 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.029012 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.027573 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.028431 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.89 MB) transferred to GPU in 0.027486 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.028337 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027343 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027727 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027594 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.028464 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.029201 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027961 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.030717 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027889 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.031242 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.027174 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.029070 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.027869 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.028058 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026962 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.93 MB) transferred to GPU in 0.028384 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.028462 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.026949 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.033967 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.030895 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.028714 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.028489 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.028699 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.028330 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.028366 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.030370 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.88 MB) transferred to GPU in 0.029344 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027773 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.027746 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.025922 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.028422 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.031083 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.030126 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.027200 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.029016 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.027439 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.030319 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.031295 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.93 MB) transferred to GPU in 0.027768 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.028493 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.030040 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.030166 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.026775 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.028239 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.034326 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.028219 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.028708 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.028509 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.026486 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.028250 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.044052 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.028233 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.028837 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.028334 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.028138 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.028794 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.035092 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.031389 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.030596 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.89 MB) transferred to GPU in 0.028889 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.93 MB) transferred to GPU in 0.029284 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.035085 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.027364 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.029187 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.028913 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.028553 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.030522 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.90 MB) transferred to GPU in 0.028687 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.91 MB) transferred to GPU in 0.030110 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 9 dense feature groups (25.92 MB) transferred to GPU in 0.029352 secs. 1 sparse feature groups

# %%
# Predict on the test set
# y_pred = bst.predict(predictkardo, num_iteration=bst.best_iteration)
y_pred = bst.predict(X_test, num_iteration=bst.best_iteration)

# Evaluate the model
rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)
# Out:
# c:\Users\krish\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
print(f'RMSE: {rmse}')
print(f'R²: {r2}')

# Optionally, save the model
# bst.save_model('lightgbm_model.txt')

# Print sample predictions
predictions_df = X_test.copy()
predictions_df['actual_position'] = y_test
predictions_df['position'] = y_pred
predictions_df
# submissions = predictions_df[['position', 'result_driver_standing']]
# print(submissions)
# Out:
# RMSE: 8.107899124960188
# R²: -0.8746336305552078
#         result_driver_standing  points_y  company  round  wins  grand_prix  \
# 0                   1410907944      28.0        9     19     0           6
# 1                   1411438560      53.0        9     19     1           6
# 2                   1412499792      78.0        9     19     2           6
# 3                   1413030408      93.0        9     19     2           6
# 4                   1413561024     103.0        9     19     2           6
# ...                        ...       ...      ...    ...   ...         ...
# 353757              1705168800     123.0        7      9     6           2
# 353758              1705815423     133.0        7      9     7           2
# 353759               297542376       6.0        7      9     0           2
# 353760               297877662       8.0        7      9     0           2
# 353761               298284795      11.0        7      9     0           2
#
#         year  points  positionOrder  resultId  racerId  actual_position  \
# 0          0    18.0              2     22109      899                8
# 1          0    18.0              2     22109      899                4
# 2          0    18.0              2     22109      899                1
# 3          0    18.0              2     22109      899                1
# 4          0    18.0              2     22109      899                3
# ...      ...     ...            ...       ...      ...              ...
# 353757     5     4.0              8     23949      997                1
# 353758     5     4.0              8     23949      997                1
# 353759     5     4.0              8     23949      997                3
# 353760     5     4.0              8     23949      997                5
# 353761     5     4.0              8     23949      997                5
#
#          position
# 0        8.374899
# 1        6.414342
# 2        6.756935
# 3        5.386139
# 4        6.661353
# ...           ...
# 353757   6.154174
# 353758   6.027173
# 353759  14.870200
# 353760  14.357299
# 353761  14.517079
#
# [353762 rows x 13 columns]

# %%
# save submission to csv
submissions.to_csv('submission.csv', index=False)
